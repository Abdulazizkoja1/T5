# %% [markdown]
# <a href="https://colab.research.google.com/github/Abdulazizkoja1/T5/blob/main/Task_(2)_Week_1(Abdulaziz_Koja).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Objective
# * The objective of this exercise is to explore and visualize the Traffic Index dataset to gain insights and understand the patterns in the data.

# %% [markdown]
# ##Dataset Description

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('/content/Task2/Task (2) Dataset.csv')

# %% [markdown]
# | Column Name | Description | Data Type |
# | :---------------- | :------: | ----: |
# |   City  |   Name of the city	   | Object |
# | Datetime           |   Date and time of the data entry	   | Object |
# |  TrafficIndexLive    |  Real-time traffic index	   | Int |
# |  Jamscount |  Number of traffic jams	   | Int |
# |   JamsDelay  |   Total delay caused by traffic jams (in minutes)	   | Float |
# |JamsLength           |   Total length of traffic jams (in kilometers)	   | Float |
# |  TrafficIndexWeekAgo    |  Traffic index one week ago	   | Int |
# |  TravelTimeHistoric |  Historical average travel time (in minutes)	   | Float |
# |   TravelTimeLive  |   Real-time travel time (in minutes)	   | Float |

# %% [markdown]
# # Tasks

# %%
df.drop('TravelTimeHistoric', axis=1, inplace=True)
df.drop('TravelTimeLive', axis=1, inplace=True)
df.isnull().sum()
# Out:
# City                   0
# Datetime               0
# TrafficIndexLive       0
# JamsCount              0
# JamsDelay              0
# JamsLength             0
# TrafficIndexWeekAgo    0
# dtype: int64

# %% [markdown]
# ## 1. Exploratory Data Analysis (EDA)

# %%
df.isnull().sum()
# Out:
# City                      0
# Datetime                  0
# TrafficIndexLive          0
# JamsCount                 0
# JamsDelay                 0
# JamsLength                0
# TrafficIndexWeekAgo       0
# TravelTimeHistoric     3867
# TravelTimeLive         3867
# dtype: int64

# %%
df.head()
# Out:
#        City             Datetime  TrafficIndexLive  JamsCount  JamsDelay  \
# 0  Abudhabi  2023-07-07 08:01:30                 6          4       15.6
# 1  Abudhabi  2023-07-07 09:01:30                 7          7       20.5
# 2  Abudhabi  2023-07-07 10:46:30                 7          8       25.0
# 3  Abudhabi  2023-07-07 11:16:30                 8         11       30.6
# 4  Abudhabi  2023-07-07 12:01:30                 8         20       62.1
#
#    JamsLength  TrafficIndexWeekAgo
# 0         0.7                   13
# 1         1.7                    8
# 2         2.8                    6
# 3         5.5                    6
# 4         6.5                    5

# %%
df.describe()
# Out:
#        TrafficIndexLive     JamsCount     JamsDelay    JamsLength  \
# count      66639.000000  66639.000000  66639.000000  66639.000000
# mean          14.043113     74.278531    288.353877     49.316135
# std           13.488906    107.452022    470.013224     85.352525
# min            0.000000      0.000000      0.000000      0.000000
# 25%            3.000000      9.000000     27.700000      3.000000
# 50%           10.000000     29.000000     95.700000     12.200000
# 75%           21.000000     95.000000    336.600000     53.500000
# max          138.000000   1359.000000   9989.400000   1173.900000
#
#        TrafficIndexWeekAgo
# count         66639.000000
# mean             13.981737
# std              13.454922
# min               0.000000
# 25%               3.000000
# 50%              10.000000
# 75%              21.000000
# max             138.000000

# %%
df.tail()
# Out:
#          City             Datetime  TrafficIndexLive  JamsCount  JamsDelay  \
# 66634  Riyadh  2023-12-15 03:01:30                 8         33      127.8
# 66635  Riyadh  2023-12-15 04:31:30                 6         27       87.0
# 66636  Riyadh  2023-12-15 05:01:30                 3         17       49.8
# 66637  Riyadh  2023-12-15 06:01:30                 0         16       61.3
# 66638  Riyadh  2023-12-15 07:01:30                 0         15       39.5
#
#        JamsLength  TrafficIndexWeekAgo
# 66634        20.4                    8
# 66635        13.8                    5
# 66636         6.7                    1
# 66637         4.3                    0
# 66638         5.2                    0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 66639 entries, 0 to 66638
# Data columns (total 7 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   City                 66639 non-null  object
#  1   Datetime             66639 non-null  object
#  2   TrafficIndexLive     66639 non-null  int64
#  3   JamsCount            66639 non-null  int64
#  4   JamsDelay            66639 non-null  float64
#  5   JamsLength           66639 non-null  float64
#  6   TrafficIndexWeekAgo  66639 non-null  int64
# dtypes: float64(2), int64(3), object(2)
# memory usage: 3.6+ MB

# %%
df.sample(5)
# Out:
#          City             Datetime  TrafficIndexLive  JamsCount  JamsDelay  \
# 39881  Jeddah  2023-10-07 17:46:00                29        107      432.2
# 31567   Dubai  2023-04-03 14:46:30                34        304     1184.5
# 43583  Kuwait  2023-03-12 02:31:30                 4         14       46.8
# 14220   Cairo  2023-09-14 17:16:30                21        155      601.6
# 7303   Al-ain  2023-11-27 15:46:00                12         11       40.7
#
#        JamsLength  TrafficIndexWeekAgo
# 39881        95.5                   28
# 31567       219.3                   31
# 43583         6.9                    3
# 14220       101.6                   18
# 7303          3.2                   10

# %% [markdown]
# ### Perform summary statistics on the dataset.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 66639 entries, 0 to 66638
# Data columns (total 9 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   City                 66639 non-null  object
#  1   Datetime             66639 non-null  object
#  2   TrafficIndexLive     66639 non-null  int64
#  3   JamsCount            66639 non-null  int64
#  4   JamsDelay            66639 non-null  float64
#  5   JamsLength           66639 non-null  float64
#  6   TrafficIndexWeekAgo  66639 non-null  int64
#  7   TravelTimeHistoric   62772 non-null  float64
#  8   TravelTimeLive       62772 non-null  float64
# dtypes: float64(4), int64(3), object(2)
# memory usage: 4.6+ MB

# %%
numerical_df = df.select_dtypes(include=['number'])
correlation_matrix = numerical_df.corr()
correlation_matrix
# Out:
#                      TrafficIndexLive  JamsCount  JamsDelay  JamsLength  \
# TrafficIndexLive             1.000000   0.876216   0.861349    0.866799
# JamsCount                    0.876216   1.000000   0.982459    0.952762
# JamsDelay                    0.861349   0.982459   1.000000    0.962679
# JamsLength                   0.866799   0.952762   0.962679    1.000000
# TrafficIndexWeekAgo          0.903282   0.806545   0.775028    0.787548
#
#                      TrafficIndexWeekAgo
# TrafficIndexLive                0.903282
# JamsCount                       0.806545
# JamsDelay                       0.775028
# JamsLength                      0.787548
# TrafficIndexWeekAgo             1.000000

# %%
df.duplicated().sum()
df.drop_duplicates(inplace=True)

# %% [markdown]
# ### Identify and analyze patterns in the data.

# %%
df.dtypes
# Out:
# City                    object
# Datetime                object
# TrafficIndexLive         int64
# JamsCount                int64
# JamsDelay              float64
# JamsLength             float64
# TrafficIndexWeekAgo      int64
# dtype: object

# %%
city = df.groupby('City').max()
print(city)
# Out:
#                      Datetime  TrafficIndexLive  JamsCount  JamsDelay  \
# City
# Abudhabi  2023-12-15 07:01:30                72        285     1289.7
# Al-ain    2023-12-15 07:46:30                33         51      250.9
# Cairo     2023-12-15 06:01:30                60        448     2601.3
# Dammam    2023-12-15 07:31:30                70        265     1979.4
# Doha      2023-12-15 07:16:30                91        511     3237.9
# Dubai     2023-12-15 08:46:30               138       1359     9989.4
# Jeddah    2023-12-15 07:01:30                89        377     2251.9
# Kuwait    2023-12-15 07:01:30                85        510     3283.8
# Mecca     2023-12-15 07:01:30                61        127      670.7
# Medina    2023-12-15 07:01:30                41         75      477.9
# Riyadh    2023-12-15 07:01:30                99        883     5466.3
#
#           JamsLength  TrafficIndexWeekAgo
# City
# Abudhabi       343.1                   72
# ...

# %% [markdown]
# ### Visualize the distribution of key variables (e.g., Traffic_Index, Date).

# %%
sns.histplot(data=df, x='TrafficIndexLive')
plt.title('Distribution of Traffic Index by City')
plt.xlabel('Traffic Index')
plt.ylabel('Frequency')
plt.show()

# %%
df.plot.hexbin(x= 'JamsDelay' , y='JamsLength' , gridsize = 10 )
# Out:
# <Axes: xlabel='JamsDelay', ylabel='JamsLength'>

# %% [markdown]
# ### Explore relationships between variables (e.g., Traffic_Index vs. Weather_Condition).

# %%
plt.figure(figsize=(12, 6))
sns.boxplot(df['TrafficIndexWeekAgo'])
plt.title('TrafficIndexWeekAgo Distribution')
plt.xlabel('TrafficIndexWeekAgo')
plt.show()

# %%
def remove_outliers(df, column):
    Q1 = df[column].quantile(0.25)
    Q3 = df[column].quantile(0.75)
    IQR = Q3 - Q1
    lower_bound = Q1 - 1.5 * IQR
    upper_bound = Q3 + 1.5 * IQR
    return df[(df[column] >= lower_bound) & (df[column] <= upper_bound)]
df = remove_outliers(df, "TrafficIndexWeekAgo")
# Out:
# (51073, 7)

# %%
plt.figure(figsize=(12, 6))
sns.boxplot(df['TrafficIndexWeekAgo'])
plt.title('TrafficIndexWeekAgo Distribution')
plt.xlabel('TrafficIndexWeekAgo')
plt.show()

# %% [markdown]
# ## 2. Data Visualization

# %%
plt.figure(figsize=(12, 6))
sns.barplot(data=df, x='City', y='JamsCount')
plt.title('Jams Count by City')
plt.xlabel('City')
plt.ylabel('Jams Count')
plt.show()

# %%
plt.figure(figsize=(12, 6))
sns.scatterplot(data=df, x='JamsCount', y='TrafficIndexWeekAgo', hue='City')
plt.title('Jams Count vs. Traffic Index Week Ago')
plt.xlabel('Jams Count')
plt.ylabel('Traffic Index Week Ago')
plt.legend(title='City')
plt.show()

# %% [markdown]
# * Ensure the visualizations are clear and informative.

# %% [markdown]
# ### Create visualizations to illustrate the findings from the EDA.

# %%
plt.figure(figsize=(12, 6))
sns.histplot(df['TrafficIndexLive'], bins=30, kde=True)
plt.title('Distribution of Traffic Index Live')
plt.xlabel('Traffic Index Live')
plt.ylabel('Frequency')
plt.show()

# %%
plt.figure(figsize=(12, 6))
sns.scatterplot(data=df, x='JamsCount', y='TrafficIndexWeekAgo', hue='City')
plt.title('Jams Count vs. Traffic Index Week Ago')
plt.xlabel('Jams Count')
plt.ylabel('Traffic Index Week Ago')
plt.legend(title='City')
plt.show()

# %% [markdown]
# ### Use appropriate plots such as histograms, bar charts, pie charts, scatter plots, and heatmaps.

# %%
plt.figure(figsize=(12, 6))
sns.histplot(df['TrafficIndexLive'], bins=30, kde=True)
plt.title('Distribution of Traffic Index Live')
plt.xlabel('Traffic Index Live')
plt.ylabel('Frequency')
plt.show()

# %%
df.boxplot()
# Out:
# <Axes: >

# %%
sns.pairplot(df)

# %%
umerical_df = df.select_dtypes(include=['number'])
corr_matrix = numerical_df.corr()
sns.heatmap(corr_matrix, annot=True)
plt.title('Correlation Matrix')
plt.show()

# %% [markdown]
# ## 3. Insights and Conclusions

# %% [markdown]
# * <h3>Summarize the key insights gained from the data analysis.<h3/>
# * <h3>Draw conclusions based on the patterns observed in the data.<h3/>

# %% [markdown]
# *   Digital data is more than textual
# *   Crowdedness in the morning is more than in the evening
