# %% [markdown]
# <a href="https://colab.research.google.com/github/Abdulazizkoja1/T5/blob/main/Task_(1)_%D9%90Abduaziz_Week_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Dataset Description

# %% [markdown]
# \
#
# ## The dataset contains information about road traffic accidents with the following columns:
#
# `Time`: Time of the accident
#
# `Day_of_week`: Day of the week when the accident occurred
#
# `Age_band_of_driver`: Age group of the driver
#
# `Sex_of_driver`: Gender of the driver
#
# `Educational_level`: Educational level of the driver
#
# `Vehicle_driver_relation`: Relationship of the driver to the vehicle
#
# `Driving_experience`: Driving experience of the driver
#
# `Type_of_vehicle`: Type of vehicle involved in the accident
#
# `Owner_of_vehicle`: Owner of the vehicle
#
# `Service_year_of_vehicle`: Service years of the vehicle
#
# `Area_accident_occured`: Area where the accident occurred
#
# `Lanes_or_Medians`: Lanes or medians at the accident site
#
# `Road_allignment`: Road alignment at the accident site
#
# `Types_of_Junction`: Type of junction at the accident site
#
# `Road_surface_type`: Type of road surface at the accident site
#
# `Road_surface_conditions`: Road surface conditions at the accident site
#
# `Light_conditions`: Light conditions at the time of the accident
#
# `Weather_conditions`: Weather conditions at the time of the accident
#
# `Type_of_collision`: Type of collision
#
# `Number_of_vehicles_involved`: Number of vehicles involved in the accident
#
# `Number_of_casualties`: Number of casualties in the accident
#
# `Vehicle_movement`: Movement of the vehicle during the accident
#
# `Casualty_class`: Class of casualty (driver, passenger, pedestrian)
#
# `Sex_of_casualty`: Gender of the casualty
#
# `Age_band_of_casualty`: Age group of the casualty
#
# `Casualty_severity`: Severity of the casualty
#
# `Work_of_casuality`: Occupation of the casualty
#
# `Fitness_of_casuality`: Fitness of the casualty
#
# `Pedestrian_movement`: Movement of the pedestrian
#
# `Cause_of_accident`: Cause of the accident
#
# `Accident_severity`: Severity of the accident

# %% [markdown]
# # Tasks

# %% [markdown]
# ##1. Data Cleaning

# %% [markdown]
# ### Read the dataset

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('Task (1) Dataset.csv')
df.head()
# Out:
#        Time Day_of_week Age_band_of_driver Sex_of_driver   Educational_level  \
# 0  17:02:00      Monday              18-30          Male   Above high school
# 1  17:02:00      Monday              31-50          Male  Junior high school
# 2  17:02:00      Monday              18-30          Male  Junior high school
# 3   1:06:00      Sunday              18-30          Male  Junior high school
# 4   1:06:00      Sunday              18-30          Male  Junior high school
#
#   Vehicle_driver_relation Driving_experience      Type_of_vehicle  \
# 0                Employee              1-2yr           Automobile
# 1                Employee         Above 10yr  Public (> 45 seats)
# 2                Employee              1-2yr      Lorry (41?100Q)
# 3                Employee             5-10yr  Public (> 45 seats)
# 4                Employee              2-5yr                  NaN
#
#   Owner_of_vehicle Service_year_of_vehicle  ... Vehicle_movement  \
# ...

# %% [markdown]
# ### Handle Missing Values

# %%
df.isnull().sum()
# Out:
# Time                              0
# Day_of_week                       0
# Age_band_of_driver                0
# Sex_of_driver                     0
# Educational_level               741
# Vehicle_driver_relation         579
# Driving_experience              829
# Type_of_vehicle                 950
# Owner_of_vehicle                482
# Service_year_of_vehicle        3928
# Defect_of_vehicle              4427
# Area_accident_occured           239
# Lanes_or_Medians                385
# Road_allignment                 142
# Types_of_Junction               887
# Road_surface_type               172
# Road_surface_conditions           0
# Light_conditions                  0
# Weather_conditions                0
# Type_of_collision               155
# Number_of_vehicles_involved       0
# Number_of_casualties              0
# Vehicle_movement                308
# Casualty_class                    0
# Sex_of_casualty                   0
# Age_band_of_casualty              0
# ...

# %%
df.drop('Service_year_of_vehicle', axis=1, inplace=True)
df.drop('Defect_of_vehicle', axis=1, inplace=True)
df.drop('Work_of_casuality', axis=1, inplace=True)
df.drop('Fitness_of_casuality', axis=1, inplace=True)
df.dropna(inplace=True)

# %%
df.dropna(inplace=True)
df.isnull().sum()
# Out:
# Time                           0
# Day_of_week                    0
# Age_band_of_driver             0
# Sex_of_driver                  0
# Educational_level              0
# Vehicle_driver_relation        0
# Driving_experience             0
# Type_of_vehicle                0
# Owner_of_vehicle               0
# Area_accident_occured          0
# Lanes_or_Medians               0
# Road_allignment                0
# Types_of_Junction              0
# Road_surface_type              0
# Road_surface_conditions        0
# Light_conditions               0
# Weather_conditions             0
# Type_of_collision              0
# Number_of_vehicles_involved    0
# Number_of_casualties           0
# Vehicle_movement               0
# Casualty_class                 0
# Sex_of_casualty                0
# Age_band_of_casualty           0
# Casualty_severity              0
# Pedestrian_movement            0
# Cause_of_accident              0
# Accident_severity              0
# dtype: int64

# %%
df.head()
# Out:
#        Time Day_of_week Age_band_of_driver Sex_of_driver   Educational_level  \
# 1  17:02:00      Monday              31-50          Male  Junior high school
# 3   1:06:00      Sunday              18-30          Male  Junior high school
# 7  17:20:00      Friday              18-30          Male  Junior high school
# 8  17:20:00      Friday              18-30          Male  Junior high school
# 9  17:20:00      Friday              18-30          Male  Junior high school
#
#   Vehicle_driver_relation Driving_experience      Type_of_vehicle  \
# 1                Employee         Above 10yr  Public (> 45 seats)
# 3                Employee             5-10yr  Public (> 45 seats)
# 7                Employee              2-5yr           Automobile
# 8                Employee         Above 10yr      Lorry (41?100Q)
# 9                Employee              1-2yr           Automobile
#
#   Owner_of_vehicle Area_accident_occured  ... Number_of_vehicles_involved  \
# ...

# %% [markdown]
# ### Correct any inconsistent data entries.

# %%
def clean_data(column):
    try:
        return float(column.split()[0])
    except (ValueError, AttributeError):
        return None
df['Age_band_of_casualty'] = df ['Age_band_of_casualty'].apply(clean_data)
df['Type_of_vehicle'] = df ['Type_of_vehicle'].apply(clean_data)
df['Age_band_of_driver'] = df['Age_band_of_driver'].str.replace(' ', '_').str.upper()
df.head()
# Out:
#                  Time Day_of_week Age_band_of_driver Sex_of_driver  \
# 1 2024-07-25 17:02:00      Monday              31-50          Male
# 3 2024-07-25 01:06:00      Sunday              18-30          Male
# 7 2024-07-25 17:20:00      Friday              18-30          Male
# 8 2024-07-25 17:20:00      Friday              18-30          Male
# 9 2024-07-25 17:20:00      Friday              18-30          Male
#
#     Educational_level Vehicle_driver_relation Driving_experience  \
# 1  Junior high school                Employee         Above 10yr
# 3  Junior high school                Employee             5-10yr
# 7  Junior high school                Employee              2-5yr
# 8  Junior high school                Employee         Above 10yr
# 9  Junior high school                Employee              1-2yr
#
#   Type_of_vehicle Owner_of_vehicle Area_accident_occured  ...  \
# 1            None            Owner          Office areas  ...
# ...

# %%
df.dropna()
# Out:
#            Time Day_of_week Age_band_of_driver Sex_of_driver  \
# 1      17:02:00      Monday              31-50          Male
# 3       1:06:00      Sunday              18-30          Male
# 7      17:20:00      Friday              18-30          Male
# 8      17:20:00      Friday              18-30          Male
# 9      17:20:00      Friday              18-30          Male
# ...         ...         ...                ...           ...
# 12309   9:05:00      Friday              31-50        Female
# 12312  18:00:00      Sunday            Unknown          Male
# 12313  13:55:00      Sunday            Over 51          Male
# 12314  13:55:00      Sunday              18-30        Female
# 12315  13:55:00      Sunday              18-30          Male
#
#         Educational_level Vehicle_driver_relation Driving_experience  \
# 1      Junior high school                Employee         Above 10yr
# 3      Junior high school                Employee             5-10yr
# ...

# %%
df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# ### Ensure data types are appropriate for each column.
#
# ---

# %%
df.dtypes
# Out:
# Time                           object
# Day_of_week                    object
# Age_band_of_driver             object
# Sex_of_driver                  object
# Educational_level              object
# Vehicle_driver_relation        object
# Driving_experience             object
# Type_of_vehicle                object
# Owner_of_vehicle               object
# Area_accident_occured          object
# Lanes_or_Medians               object
# Road_allignment                object
# Types_of_Junction              object
# Road_surface_type              object
# Road_surface_conditions        object
# Light_conditions               object
# Weather_conditions             object
# Type_of_collision              object
# Number_of_vehicles_involved     int64
# Number_of_casualties            int64
# Vehicle_movement               object
# Casualty_class                 object
# Sex_of_casualty                object
# Age_band_of_casualty           object
# Casualty_severity              object
# ...

# %%
df['Time'] = pd.to_datetime(df['Time'])
# Out:
# <ipython-input-13-1bfd8981fe14>:1: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df['Time'] = pd.to_datetime(df['Time'])

# %%
df['Casualty_class'] = df['Casualty_class'].fillna(df['Casualty_class'].mode()[0])
print(df['Casualty_class'])
# Out:
# 1                     na
# 3             Pedestrian
# 7                     na
# 8             Pedestrian
# 9              Passenger
#               ...
# 12309    Driver or rider
# 12312                 na
# 12313    Driver or rider
# 12314                 na
# 12315         Pedestrian
# Name: Casualty_class, Length: 8439, dtype: object

# %% [markdown]
# ## 2. Exploratory Data Analysis (EDA)

# %%
df.head()
# Out:
#        Time Day_of_week Age_band_of_driver Sex_of_driver   Educational_level  \
# 1  17:02:00      Monday              31-50          Male  Junior high school
# 3   1:06:00      Sunday              18-30          Male  Junior high school
# 7  17:20:00      Friday              18-30          Male  Junior high school
# 8  17:20:00      Friday              18-30          Male  Junior high school
# 9  17:20:00      Friday              18-30          Male  Junior high school
#
#   Vehicle_driver_relation Type_of_vehicle Owner_of_vehicle  \
# 1                Employee            None            Owner
# 3                Employee            None     Governmental
# 7                Employee            None     Governmental
# 8                Employee            None            Owner
# 9                Employee            None            Owner
#
#   Area_accident_occured   Lanes_or_Medians  ... Number_of_vehicles_involved  \
# ...

# %%
df.describe()
# Out:
#                                 Time  Number_of_vehicles_involved  \
# count                           8439                  8439.000000
# mean   2024-07-25 14:15:48.169214208                     2.038038
# min              2024-07-25 00:01:00                     1.000000
# 25%              2024-07-25 10:30:00                     2.000000
# 50%              2024-07-25 15:10:00                     2.000000
# 75%              2024-07-25 18:09:00                     2.000000
# max              2024-07-25 23:59:00                     7.000000
# std                              NaN                     0.680789
#
#        Number_of_casualties
# count           8439.000000
# mean               1.547340
# min                1.000000
# 25%                1.000000
# 50%                1.000000
# 75%                2.000000
# max                8.000000
# std                1.014755

# %%
df.tail()
# Out:
#            Time Day_of_week Age_band_of_driver Sex_of_driver  \
# 12309   9:05:00      Friday              31-50        Female
# 12312  18:00:00      Sunday            Unknown          Male
# 12313  13:55:00      Sunday            Over 51          Male
# 12314  13:55:00      Sunday              18-30        Female
# 12315  13:55:00      Sunday              18-30          Male
#
#         Educational_level Vehicle_driver_relation Type_of_vehicle  \
# 12309   Elementary school                Employee            None
# 12312   Elementary school                Employee            None
# 12313  Junior high school                Employee            None
# 12314  Junior high school                Employee            None
# 12315  Junior high school                Employee            None
#
#       Owner_of_vehicle Area_accident_occured  \
# 12309            Owner          School areas
# 12312            Owner   Outside rural areas
# 12313            Owner   Outside rural areas
# ...

# %%
df.sample(5)
# Out:
#            Time Day_of_week Age_band_of_driver Sex_of_driver  \
# 6624   18:40:00    Saturday              18-30          Male
# 11609  15:20:00      Sunday            Over 51          Male
# 5716   16:00:00      Friday              31-50          Male
# 2900   17:52:00      Monday            Unknown        Female
# 2723   23:00:00    Thursday              31-50          Male
#
#         Educational_level Vehicle_driver_relation Type_of_vehicle  \
# 6624   Junior high school                Employee            None
# 11609  Junior high school                Employee            None
# 5716   Junior high school                   Owner            None
# 2900   Junior high school                Employee            None
# 2723    Elementary school                Employee            None
#
#       Owner_of_vehicle Area_accident_occured             Lanes_or_Medians  \
# 6624             Owner                 Other                      One way
# ...

# %% [markdown]
# ### Perform summary statistics on the dataset.

# %%
df.describe()
# Out:
#        Number_of_vehicles_involved  Number_of_casualties  Age_band_of_casualty
# count                  8633.000000           8633.000000                 159.0
# mean                      2.038920              1.547203                   5.0
# std                       0.681998              1.015919                   0.0
# min                       1.000000              1.000000                   5.0
# 25%                       2.000000              1.000000                   5.0
# 50%                       2.000000              1.000000                   5.0
# 75%                       2.000000              2.000000                   5.0
# max                       7.000000              8.000000                   5.0

# %%
plt.figure(figsize=(12, 6))
sns.boxplot(df['Number_of_vehicles_involved'])
plt.title('Number_of_vehicles_involved')
plt.xlabel('Number')
plt.show()

# %%
def remove_outliers(df, column):
    Q1 = df[column].quantile(0.25)
    Q3 = df[column].quantile(0.75)
    IQR = Q3 - Q1
    lower_bound = Q1 - 1.5 * IQR
    upper_bound = Q3 + 1.5 * IQR
    return df[(df[column] >= lower_bound) & (df[column] <= upper_bound)]
df = remove_outliers(df, "Number_of_vehicles_involved")

# %%
plt.figure(figsize=(12, 6))
sns.boxplot(df['Number_of_vehicles_involved'])
plt.title('Number_of_vehicles_involved')
plt.xlabel('Number')
plt.show()

# %% [markdown]
# ### Identify and analyze patterns in the data.

# %%
numerical_df = df.select_dtypes(include=['number'])
correlation_matrix = numerical_df.corr()
correlation_matrix
# Out:
#                              Number_of_vehicles_involved  Number_of_casualties
# Number_of_vehicles_involved                          NaN                   NaN
# Number_of_casualties                                 NaN                   1.0

# %%
df.head()
# Out:
#                  Time Day_of_week Age_band_of_driver Sex_of_driver  \
# 1 2024-07-25 17:02:00      Monday              31-50          Male
# 3 2024-07-25 01:06:00      Sunday              18-30          Male
# 7 2024-07-25 17:20:00      Friday              18-30          Male
# 8 2024-07-25 17:20:00      Friday              18-30          Male
# 9 2024-07-25 17:20:00      Friday              18-30          Male
#
#     Educational_level Vehicle_driver_relation Driving_experience  \
# 1  Junior high school                Employee         Above 10yr
# 3  Junior high school                Employee             5-10yr
# 7  Junior high school                Employee              2-5yr
# 8  Junior high school                Employee         Above 10yr
# 9  Junior high school                Employee              1-2yr
#
#   Type_of_vehicle Owner_of_vehicle Area_accident_occured  ...  \
# 1            None            Owner          Office areas  ...
# ...

# %% [markdown]
# ### Visualize the distribution of key variables (e.g., Age_band_of_driver, Type_of_vehicle).

# %%
plt.figure(figsize=(10, 6))
plt.hist(df['Age_band_of_driver'], bins=10)
plt.title('Age_band_of_driver of Casualties')
plt.xlabel('Age')
plt.show()

# %% [markdown]
# ### Explore relationships between variables (e.g., Age_band_of_driver vs. Accident_severity).

# %%
sns.scatterplot(data= df, x='Accident_severity', y='Age_band_of_driver', color='Blue')
sns.displot(data= df, x='Accident_severity', height=6, aspect=2)
plt.title('Relationship Between Age bandof driver and Accident severity')
plt.xlabel('Accident')
plt.ylabel('Age')
plt.show()

# %% [markdown]
# ## 3. Data Visualization

# %%
plt.figure(figsize=(10, 6))
sns.pairplot(df)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# * Ensure the visualizations are clear and informative.

# %%
sns.heatmap(correlation_matrix, annot=True)
# Out:
# <Axes: >

# %% [markdown]
# ### Create visualizations to illustrate the findings from the EDA.

# %% [markdown]
# ### Use appropriate plots such as histograms, bar charts, pie charts, scatter plots, and heatmaps.

# %%
grouped_data = df.groupby(['Sex_of_driver', 'Driving_experience']).size().unstack().fillna(0)
grouped_data.plot(kind='bar', stacked=True, figsize=(10, 6))
plt.title('Driving Experience by Sex of Driver')
plt.xlabel('Sex of Driver')
plt.ylabel('Count')
plt.xticks(rotation=0)
plt.legend(title='Driving Experience')
plt.show()

# %%
plt.figure(figsize=(10, 6))
sns.displot(data= df, x='Accident_severity')
plt.title('Accident_severity_Distribution')
plt.xlabel('Accident_severity')
plt.show()

# %% [markdown]
# ## 4. Insights and Conclusions

# %% [markdown]
# * <h3>Summarize the key insights gained from the data analysis.<h3/>
# * <h3>Draw conclusions based on the patterns observed in the data.<h3/>

# %% [markdown]
# *   In the first code I only got two in( Identify and analyze patterns in the data)
# *   Textual data is more than digital
