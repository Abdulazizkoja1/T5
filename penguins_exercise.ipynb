# %% [markdown]
# <a href="https://colab.research.google.com/github/Abdulazizkoja1/T5/blob/main/penguins_exercise.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # EDA on Penguins

# %% [markdown]
# In this notebook exercise, we will conduct simple EDA steps on the popular penguins dataset.

# %% [markdown]
# ### Load the dataset
#
# Dataset source: https://github.com/allisonhorst/palmerpenguins

# %%
import seaborn as sns

# %%
df = sns.load_dataset('penguins')

# %%
df.shape
# Out:
# (344, 7)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 344 entries, 0 to 343
# Data columns (total 7 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   species            344 non-null    object
#  1   island             344 non-null    object
#  2   bill_length_mm     342 non-null    float64
#  3   bill_depth_mm      342 non-null    float64
#  4   flipper_length_mm  342 non-null    float64
#  5   body_mass_g        342 non-null    float64
#  6   sex                333 non-null    object
# dtypes: float64(4), object(3)
# memory usage: 18.9+ KB

# %% [markdown]
# # Step 1 Understand the Features
#
# You can find information about this dataset here: https://www.kaggle.com/code/parulpandey/penguin-dataset-the-new-iris
#
# **Question: in your own words**:
# 1. describe each feature
# 2. mention its type (numeric or categorical)
# 3. write its name in Arabic
#
# Note: use a Markdown cell.

# %% [markdown]
# Hint: you can attach an image to illustrate what the features are.

# %% [markdown]
# <img src="https://github.com/allisonhorst/palmerpenguins/raw/main/man/figures/culmen_depth.png" width="400">

# %% [markdown]
# # Task One
#
# 1. **species**
#    - **Description**: The species of the penguin.
#    - **Type**: Categorical
#    - **Arabic**: النوع
#
# 2. **island**
#    - **Description**: The island in the Palmer Archipelago where the penguin was observed.
#    - **Type**: Categorical
#    - **Arabic**: الجزيرة
#
# 3. **bill_length_mm**
#    - **Description**: The length of the penguin's bill in millimeters.
#    - **Type**: Numeric
#    - **Arabic**: طول المنقار (ملم)
#
# 4. **bill_depth_mm**
#    - **Description**: The depth of the penguin's bill in millimeters.
#    - **Type**: Numeric
#    - **Arabic**: عمق المنقار (ملم)
#
# 5. **flipper_length_mm**
#    - **Description**: The length of the penguin's flipper in millimeters.
#    - **Type**: Numeric
#    - **Arabic**: طول الزعنفة (ملم)
#
# 6. **body_mass_g**
#    - **Description**: The body mass of the penguin in grams.
#    - **Type**: Numeric
#    - **Arabic**: كتلة الجسم (جم)
#
# 7. **sex**
#    - **Description**: The sex of the penguin.
#    - **Type**: Categorical
#    - **Arabic**: الجنس
#
# 8. **year**
#    - **Description**: The year the observation was made.
#    - **Type**: Numeric
#    - **Arabic**: السنة

# %%
df.head()
# Out:
#   species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0  Adelie  Torgersen            39.1           18.7              181.0
# 1  Adelie  Torgersen            39.5           17.4              186.0
# 2  Adelie  Torgersen            40.3           18.0              195.0
# 3  Adelie  Torgersen             NaN            NaN                NaN
# 4  Adelie  Torgersen            36.7           19.3              193.0
#
#    body_mass_g     sex
# 0       3750.0    Male
# 1       3800.0  Female
# 2       3250.0  Female
# 3          NaN     NaN
# 4       3450.0  Female

# %% [markdown]
# # Step 2

# %% [markdown]
# - Have a look at the columns and their values (`head`, `sample`, `tail`)
# - Look at the technical information (`info`)

# %%
df.head()
# Out:
#   species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0  Adelie  Torgersen            39.1           18.7              181.0
# 1  Adelie  Torgersen            39.5           17.4              186.0
# 2  Adelie  Torgersen            40.3           18.0              195.0
# 3  Adelie  Torgersen             NaN            NaN                NaN
# 4  Adelie  Torgersen            36.7           19.3              193.0
#
#    body_mass_g     sex
# 0       3750.0    Male
# 1       3800.0  Female
# 2       3250.0  Female
# 3          NaN     NaN
# 4       3450.0  Female

# %%
df.sample(5)
# Out:
#        species  island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 308     Gentoo  Biscoe            47.5           14.0              212.0
# 139     Adelie   Dream            39.7           17.9              193.0
# 342     Gentoo  Biscoe            45.2           14.8              212.0
# 152  Chinstrap   Dream            46.5           17.9              192.0
# 142     Adelie   Dream            32.1           15.5              188.0
#
#      body_mass_g     sex
# 308       4875.0  Female
# 139       4250.0    Male
# 342       5200.0  Female
# 152       3500.0  Female
# 142       3050.0  Female

# %%
df.tail()
# Out:
#     species  island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 339  Gentoo  Biscoe             NaN            NaN                NaN
# 340  Gentoo  Biscoe            46.8           14.3              215.0
# 341  Gentoo  Biscoe            50.4           15.7              222.0
# 342  Gentoo  Biscoe            45.2           14.8              212.0
# 343  Gentoo  Biscoe            49.9           16.1              213.0
#
#      body_mass_g     sex
# 339          NaN     NaN
# 340       4850.0  Female
# 341       5750.0    Male
# 342       5200.0  Female
# 343       5400.0    Male

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 344 entries, 0 to 343
# Data columns (total 7 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   species            344 non-null    object
#  1   island             344 non-null    object
#  2   bill_length_mm     342 non-null    float64
#  3   bill_depth_mm      342 non-null    float64
#  4   flipper_length_mm  342 non-null    float64
#  5   body_mass_g        342 non-null    float64
#  6   sex                333 non-null    object
# dtypes: float64(4), object(3)
# memory usage: 18.9+ KB

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 344 entries, 0 to 343
# Data columns (total 7 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   species            344 non-null    object
#  1   island             344 non-null    object
#  2   bill_length_mm     342 non-null    float64
#  3   bill_depth_mm      342 non-null    float64
#  4   flipper_length_mm  342 non-null    float64
#  5   body_mass_g        342 non-null    float64
#  6   sex                333 non-null    object
# dtypes: float64(4), object(3)
# memory usage: 18.9+ KB

# %% [markdown]
# # Step 3
#
# 1. For each column, check and handle missing values; state your strategy and justify it. Examples:
#     - Strategy: drop the column. Justification: ...?
#     - Strategy: fill missing values. Justificaiton: ...?
#     - Strategy: drop the row. Justification: ...?
# 1. Calculate count and percentage of missing values before handling them
# 1. Check and handle duplicated rows
# 1. Calculate the percentage of data loss after cleaning

# %%
df['sex'].fillna(df['sex'].mode()[0], inplace=True)

# %%
df.isnull().sum()
# Out:
# species              0
# island               0
# bill_length_mm       2
# bill_depth_mm        2
# flipper_length_mm    2
# body_mass_g          2
# sex                  0
# dtype: int64

# %%
df.dropna(inplace=True)

# %%
missing_values = df.isnull().sum()
missing_values
# Out:
# species              0
# island               0
# bill_length_mm       0
# bill_depth_mm        0
# flipper_length_mm    0
# body_mass_g          0
# sex                  0
# dtype: int64

# %%
print("Missing values count:\n", missing_values)
# Out:
# Missing values count:
#  species              0
# island               0
# bill_length_mm       0
# bill_depth_mm        0
# flipper_length_mm    0
# body_mass_g          0
# sex                  0
# dtype: int64

# %%
df = df.drop_duplicates()

# %%
num_duplicate_rows_after = df.duplicated().sum()
print("\nNumber of duplicated rows after handling:", num_duplicate_rows_after)
# Out:
# Number of duplicated rows after handling: 0

# %%
rows_before = 344
rows_after = len(df)

# %%
data_loss_percentage = ((rows_before - rows_after) / rows_before) * 100

# %%
print("{:.2f}%".format(data_loss_percentage))
# Out:
# 0.58%

# %% [markdown]
# # Step 4

# %% [markdown]
# #### Data types conversion
# - We shall convert the string types to `category` to preserve memory
# - numeric types can be stored in less precision: `float32`

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 342 entries, 0 to 343
# Data columns (total 7 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   species            342 non-null    object
#  1   island             342 non-null    object
#  2   bill_length_mm     342 non-null    float64
#  3   bill_depth_mm      342 non-null    float64
#  4   flipper_length_mm  342 non-null    float64
#  5   body_mass_g        342 non-null    float64
#  6   sex                342 non-null    object
# dtypes: float64(4), object(3)
# memory usage: 21.4+ KB

# %%
mem_usage_before = df.memory_usage(deep=True)

# %%
# convert categotical types
df['species'] = df['species'].astype('category')
df['island'] = df['island'].astype('category')
df['sex'] = df['sex'].astype('category')

# %%
# convert numerical types
df['bill_length_mm'] = df['bill_length_mm'].astype('float32')
df['bill_depth_mm'] = df['bill_depth_mm'].astype('float32')
df['flipper_length_mm'] = df['flipper_length_mm'].astype('float32')
df['body_mass_g'] = df['body_mass_g'].astype('float32')

# %% [markdown]
# Calculate memory saved after type conversion

# %%
# mem_usage_after = ...?
mem_usage_after = df.memory_usage(deep=True)

# %%
print('memory saved:', (mem_usage_before - mem_usage_after).sum() // 1024, 'KB')
# Out:
# memory saved: 66 KB

# %% [markdown]
# # Step 5

# %% [markdown]
# #### Detect inconsistency in categorical values

# %% [markdown]
# The categorical columns should be checked for any inconsistencies. For example. We look for lowercase, uppercase, or inconsistent use of codes (e.g., "M", "F") with non-codes (e.g., "Male", "Female")  in the `sex` column.

# %% [markdown]
# - hint: use `.unique()` to check the number of unique values in a column
# - you can also use: `.value_counts()` to check the frequency of each value in a column

# %%
df.head()
# Out:
#   species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0  Adelie  Torgersen       39.099998      18.700001              181.0
# 1  Adelie  Torgersen       39.500000      17.400000              186.0
# 2  Adelie  Torgersen       40.299999      18.000000              195.0
# 4  Adelie  Torgersen       36.700001      19.299999              193.0
# 5  Adelie  Torgersen       39.299999      20.600000              190.0
#
#    body_mass_g     sex
# 0       3750.0    Male
# 1       3800.0  Female
# 2       3250.0  Female
# 4       3450.0  Female
# 5       3650.0    Male

# %%
df['species'].unique()
# Out:
# ['Adelie', 'Chinstrap', 'Gentoo']
# Categories (3, object): ['Adelie', 'Chinstrap', 'Gentoo']

# %%
df['island'].unique()
# Out:
# ['Torgersen', 'Biscoe', 'Dream']
# Categories (3, object): ['Biscoe', 'Dream', 'Torgersen']

# %%
df['sex'].unique()
# Out:
# ['Male', 'Female']
# Categories (2, object): ['Female', 'Male']

# %% [markdown]
# # Step 6: Univariate Analysis

# %% [markdown]
# - Separate numerical from categorical columns (hint; use `df.select_dtypes()`)
# - Look at the statistical information for each:
#     - `df_num.describe().T`
#     - `df_cat.describe().T`

# %%
df_num = df.select_dtypes(include='float32')

df_num.describe()
# Out:
#        bill_length_mm  bill_depth_mm  flipper_length_mm  body_mass_g
# count      342.000000     342.000000         342.000000   342.000000
# mean        43.921932      17.151171         200.915207  4201.754395
# std          5.459584       1.974793          14.061714   801.954529
# min         32.099998      13.100000         172.000000  2700.000000
# 25%         39.225000      15.600000         190.000000  3550.000000
# 50%         44.450001      17.299999         197.000000  4050.000000
# 75%         48.500000      18.700001         213.000000  4750.000000
# max         59.599998      21.500000         231.000000  6300.000000

# %%
df_cat = df.select_dtypes(include='category')
df_cat.describe()
# Out:
#        species  island   sex
# count      342     342   342
# unique       3       3     2
# top     Adelie  Biscoe  Male
# freq       151     167   177

# %% [markdown]
# Use charts to plot `value_counts()` categorical variables:
# 1. plot `species` using bar plot
# 1. plot `island` using pie chart
# 1. plot `sex` using horizontal bar plot

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
#1
plt.figure(figsize=(8, 6))
sns.countplot(data=df, x='species', color = 'yellow')
plt.title('Count of Penguins by Species')
plt.xlabel('Species')
plt.ylabel('Count')
plt.show()

# %%
#2
plt.figure(figsize=(8, 6))
df['island'].value_counts().plot.pie(autopct='%1.1f%%', startangle=90, colors=sns.color_palette('pastel'))
plt.title('Distribution of Penguins by Island')
plt.show()

# %%
#3
plt.figure(figsize=(8, 6))
sns.countplot(data=df, y='sex', order=df['sex'].value_counts().index, color = 'orange')
plt.title('Count of Penguins by Sex')
plt.xlabel('Count')
plt.ylabel('Sex')
plt.show()

# %% [markdown]
# Plot numerical variables:
#
# 1. Boxplot: `bill_length_mm`
# 1. Histogram: `bill_depth_mm`
# 1. Boxplot: `flipper_length_mm`
# 1. Histogram: `body_mass_g`

# %%
#1
plt.figure(figsize=(8, 6))
sns.boxplot(data=df, x='bill_length_mm', color = 'Blue')
plt.title('Boxplot of Bill Length (mm)')
plt.xlabel('Bill Length (mm)')
plt.show()

# %%
#2
plt.figure(figsize=(8, 6))
sns.histplot(data=df, x='bill_depth_mm', bins=20, kde=True,color='green')
plt.title('Histogram of Bill Depth (mm)')
plt.xlabel('Bill Depth (mm)')
plt.ylabel('Frequency')
plt.show()

# %%
#3
plt.figure(figsize=(8, 6))
sns.boxplot(data=df, x='flipper_length_mm', color='red')
plt.title('Boxplot of Flipper Length (mm)')
plt.xlabel('Flipper Length (mm)')
plt.show()

# %%
#4
plt.figure(figsize=(8, 6))
sns.histplot(data=df, x='body_mass_g', bins=20, kde=True, color='purple')
plt.title('Histogram of Body Mass (g)')
plt.xlabel('Body Mass (g)')
plt.ylabel('Frequency')
plt.show()

# %% [markdown]
# ## Step 7: Bivariate Analysis
#
# #### Correlation between numerical features
#
# Let's find out if there is any correlation between numerical features.

# %% [markdown]
# - Hint: you can use the `df.corr()` to find the correlation matrix.
# - Hint: you can use `sns.heatmap()` to plot the correlation matrix

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
#df['species'] = le.fit_transform(df['species'])
#df['sex'] = df['sex'].map({'MALE': 0, 'FEMALE': 1})
#df['island'] = le.fit_transform(df['island'])
correlation_matrix = df.select_dtypes(include='float32').corr()

# %%
plt.figure(figsize=(10, 8))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', linewidths=0.5)
plt.title('Correlation Matrix of Numerical Features')
plt.show()

# %% [markdown]
# ##### Correlations in the Penguin Dataset:
#
# **Bill Measurements**:
# - The strongest positive correlation is between `bill_length_mm` and `flipper_length_mm` (0.66).
# - The strongest negative correlation is between `bill_depth_mm` and `flipper_length_mm` (-0.58).
#
# **Flipper Length and Body Mass**:
# - The strongest positive correlation is between `flipper_length_mm` and `body_mass_g` (0.87).
#
# Observations:

# %% [markdown]
# ### Feature Engineering
#
# - We might try adding the feature `bill_size` which is the product of `bill_length` and `bill_depth` to see if it has any significance in the model.
# - We might also try `bill_ratio` which is the ratio of `bill_length` to `bill_depth` to see if it has any significance in the model.

# %%
df['bill_size'] = df['bill_length_mm'] * df['bill_depth_mm']
df.head()
# Out:
#   species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0  Adelie  Torgersen       39.099998      18.700001              181.0
# 1  Adelie  Torgersen       39.500000      17.400000              186.0
# 2  Adelie  Torgersen       40.299999      18.000000              195.0
# 4  Adelie  Torgersen       36.700001      19.299999              193.0
# 5  Adelie  Torgersen       39.299999      20.600000              190.0
#
#    body_mass_g     sex   bill_size
# 0       3750.0    Male  731.169983
# 1       3800.0  Female  687.299988
# 2       3250.0  Female  725.399963
# 4       3450.0  Female  708.309998
# 5       3650.0    Male  809.580017

# %%
df['bill_ratio'] = df['bill_length_mm'] / df['bill_depth_mm']
df.head()
# Out:
#   species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0  Adelie  Torgersen       39.099998      18.700001              181.0
# 1  Adelie  Torgersen       39.500000      17.400000              186.0
# 2  Adelie  Torgersen       40.299999      18.000000              195.0
# 4  Adelie  Torgersen       36.700001      19.299999              193.0
# 5  Adelie  Torgersen       39.299999      20.600000              190.0
#
#    body_mass_g     sex   bill_size  bill_ratio
# 0       3750.0    Male  731.169983    2.090909
# 1       3800.0  Female  687.299988    2.270115
# 2       3250.0  Female  725.399963    2.238889
# 4       3450.0  Female  708.309998    1.901554
# 5       3650.0    Male  809.580017    1.907767

# %% [markdown]
# Let's look at the correlation to see whether the newly created features are better.

# %%
# This plots the correlation values for a specific column
corr = df.select_dtypes(['float32']).corr()

# which is usually what we are interested in
corr['bill_size'].sort_values().plot.barh()
corr['bill_ratio'].sort_values().plot.barh()
# Out:
# <Axes: >
